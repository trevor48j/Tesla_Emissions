# %%
# %matplotlib inline

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import textwrap

from matplotlib.ticker import MaxNLocator

# %%
# Import our data into pandas from CSV
happy_reports = "Resources/clean_data/data_country_all.csv"
happy_reports_df = pd.read_csv(happy_reports)

happy_reports_df
# Out:
#      Year            Country              Region  Happiness Rank  \
# 0    2015        Switzerland      Western Europe               1
# 1    2016        Switzerland      Western Europe               2
# 2    2017        Switzerland      Western Europe               4
# 3    2018        Switzerland      Western Europe               5
# 4    2019        Switzerland      Western Europe               6
# ..    ...                ...                 ...             ...
# 777  2019  Trinidad & Tobago  Sub-Saharan Africa              39
# 778  2018    Northern Cyprus  Sub-Saharan Africa              58
# 779  2019    Northern Cyprus  Sub-Saharan Africa              64
# 780  2019    North Macedonia  Sub-Saharan Africa              84
# 781  2019             Gambia  Sub-Saharan Africa             120
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0              7.587                   1.39651  1.349510
# 1              7.509                   1.52733  1.145240
# 2              7.494                   1.56498  1.516912
# 3              7.487                   1.42000  1.549000
# 4              7.480                   1.45200  1.526000
# ..               ...                       ...       ...
# 777            6.192                   1.23100  1.477000
# 778            5.835                   1.22900  1.211000
# 779            5.718                   1.26300  1.252000
# 780            5.274                   0.98300  1.294000
# 781            4.516                   0.30800  0.939000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    0.941430  0.665570                       0.419780
# 1                    0.863030  0.585570                       0.412030
# 2                    0.858131  0.620071                       0.367007
# 3                    0.927000  0.660000                       0.357000
# 4                    1.052000  0.572000                       0.343000
# ..                        ...       ...                            ...
# 777                  0.713000  0.489000                       0.016000
# 778                  0.909000  0.495000                       0.154000
# 779                  1.042000  0.417000                       0.162000
# 780                  0.838000  0.345000                       0.034000
# 781                  0.428000  0.382000                       0.167000
#
#      Generosity  Dystopia Residual  Avg Happiness Rank
# 0      0.296780           2.517380                 3.6
# 1      0.280830           2.694630                 3.6
# 2      0.290549           2.276716                 3.6
# 3      0.256000           2.276716                 3.6
# 4      0.263000           2.276716                 3.6
# ..          ...                ...                 ...
# 777    0.185000           0.554633                15.4
# 778    0.179000           0.554633                24.4
# 779    0.191000           0.554633                24.4
# 780    0.185000           0.554633                16.8
# 781    0.269000           0.554633                24.0
#
# [782 rows x 13 columns]

# %%
# Sort based upon multiple columns
year_happiness_rank_df = happy_reports_df.sort_values(
    by=["Year", "Happiness Rank"], 
    ascending=True
)
year_happiness_rank_df.head(20)
# Out:
#     Year               Country                           Region  \
# 0   2015           Switzerland                   Western Europe
# 5   2015               Iceland                   Western Europe
# 10  2015               Denmark                   Western Europe
# 15  2015                Norway                   Western Europe
# 20  2015                Canada                    North America
# 25  2015               Finland                   Western Europe
# 30  2015           Netherlands                   Western Europe
# 35  2015                Sweden                   Western Europe
# 40  2015           New Zealand        Australia and New Zealand
# 45  2015             Australia        Australia and New Zealand
# 50  2015                Israel  Middle East and Northern Africa
# 90     0.22250            2.41484                17.6
# 95     0.26428            2.24743                22.0

# %%
happy_reports_df.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(12,6),color='lightblue')
plt.title('Top 20 Happiest Countries')
plt.savefig("Images/bar_top20_country.png")

# %%
happy_reports_df.groupby('Country')['Happiness Score'].max().sort_values(ascending=True).head(20).plot(kind='bar', figsize=(12,6),color='red')
plt.title('Least Happiest Countries')
plt.savefig("Images/bar_top20_country.png")

# %%
year_happiness_rank_df.groupby('Country')['Happiness Score'].max().sort_values(ascending=False).head(20).plot(kind='bar', figsize=(12,6),color='gold')
plt.title('Top 20 happiest countries')
# Out:
# Text(0.5, 1.0, 'Top 20 happiest countries')

# %%
region_mean = happy_reports_df.groupby('Region')['Happiness Score'].mean().sort_values(ascending=False)
fig, ax = plt.subplots(1, 1, figsize=(15, 7))
plot = sns.barplot(x=region_mean.index, y=region_mean, ax=ax, palette=sns.color_palette("Blues", len(region_mean)))
i = 0
for index, row in region_mean.iteritems():
    plot.text(x=i, y=row*1.01, s=round(row, 2), 
            ha='center', color='black')
    i += 1

ax.set_title('Region and Happiness Score (Mean)', fontdict={'fontweight':'bold'})
ax.set_xlabel('Region', fontweight='bold')
ax.set_ylabel('Happiness Score', fontweight='bold')
ax.set_xticklabels(textwrap.fill(x.get_text(), 10, subsequent_indent='-') for x in ax.get_xticklabels())
plt.savefig("Images/bar_score_region_mean.png")
plt.show()

# %%
# Gloabal changes of happiness factors over the years 
columns = ['Economy (GDP per Capita)','Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity']
year_mean = happy_reports_df.groupby(by=['Year'])[columns].mean()
year_mean
# Out:
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# Year
# 2015                  0.846137  0.991046                  0.630259  0.428615
# 2016                  0.953880  0.793621                  0.557619  0.370994
# 2017                  0.984718  1.188898                  0.551341  0.408786
# 2018                  0.891449  1.213237                  0.597346  0.454506
# 2019                  0.905147  1.208814                  0.725244  0.392571
#
#       Trust (Government Corruption)  Generosity
# Year
# 2015                       0.143422    0.237296
# 2016                       0.137624    0.242635
# 2017                       0.123120    0.246883
# 2018                       0.113362    0.181006
# 2019                       0.110603    0.184846

# %%
fig, ax = plt.subplots(1, 1, figsize=(13, 9))
for column in columns:
    plot = sns.lineplot(x=year_mean.index, y=year_mean[column], ax=ax, 
               label=column, marker='o')

    for index, value in year_mean[column].iteritems():
        plot.text(x=index, y=round(value, 2)*1.02, s=round(value, 2), 
                  ha='center', color='black')

ax.set_title('Global Changes of Happiness Factors Over The Years', fontweight='bold')
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel('Year', fontweight='bold')
ax.set_ylabel('Mean Value', fontweight='bold')
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='center left', bbox_to_anchor=(1, 0.5))
ax.grid(False)
plt.savefig("Images/line_global_changes_mean.png")
plt.show()
