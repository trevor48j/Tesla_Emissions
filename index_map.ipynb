# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\krist\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: six in c:\users\krist\anaconda3\lib\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\krist\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chart_studio
# Out:
# Collecting chart_studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: plotly in c:\users\krist\anaconda3\lib\site-packages (from chart_studio) (5.1.0)
# Requirement already satisfied: requests in c:\users\krist\anaconda3\lib\site-packages (from chart_studio) (2.25.1)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in c:\users\krist\anaconda3\lib\site-packages (from chart_studio) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\krist\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\krist\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\krist\anaconda3\lib\site-packages (from requests->chart_studio) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krist\anaconda3\lib\site-packages (from requests->chart_studio) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\krist\anaconda3\lib\site-packages (from requests->chart_studio) (4.0.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11429 sha256=82eede2bab52174f871a9f65f7a3eaef017d81ecb1015a37117b1049aba6c68c
#   Stored in directory: c:\users\krist\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, chart-studio
# Successfully installed chart-studio-1.1.0 retrying-1.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import scipy.stats as sts
import pandas as pd
import numpy as np

#Call required libraries
import time                   # To time processes
import warnings               # To suppress warnings

import numpy as np            # Data manipulation
import pandas as pd           # Dataframe manipulatio 
import matplotlib.pyplot as plt                   # For graphics
import seaborn as sns
import chart_studio.plotly.plotly as py #For World Map
# import chart_studio.graph_objs as go
# from chart_studio.plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# init_notebook_mode(connected=True)

from sklearn.preprocessing import StandardScaler  # For scaling dataset
from sklearn.cluster import KMeans, AgglomerativeClustering, AffinityPropagation #For clustering
from sklearn.mixture import GaussianMixture #For GMM clustering

import os                     # For os related operations
import sys                    # For data size

# %%
wh = pd.read_csv('./Resources/clean_data/data_country_all.csv')

# %%
wh
# Out:
#      Year            Country              Region  Happiness Rank  \
# 0    2015        Switzerland      Western Europe               1
# 1    2016        Switzerland      Western Europe               2
# 2    2017        Switzerland      Western Europe               4
# 3    2018        Switzerland      Western Europe               5
# 4    2019        Switzerland      Western Europe               6
# ..    ...                ...                 ...             ...
# 777  2019  Trinidad & Tobago  Sub-Saharan Africa              39
# 778  2018    Northern Cyprus  Sub-Saharan Africa              58
# 779  2019    Northern Cyprus  Sub-Saharan Africa              64
# 780  2019    North Macedonia  Sub-Saharan Africa              84
# 781  2019             Gambia  Sub-Saharan Africa             120
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0              7.587                   1.39651  1.349510
# 1              7.509                   1.52733  1.145240
# 2              7.494                   1.56498  1.516912
# 3              7.487                   1.42000  1.549000
# 4              7.480                   1.45200  1.526000
# ..               ...                       ...       ...
# 777            6.192                   1.23100  1.477000
# 778            5.835                   1.22900  1.211000
# 779            5.718                   1.26300  1.252000
# 780            5.274                   0.98300  1.294000
# 781            4.516                   0.30800  0.939000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    0.941430  0.665570                       0.419780
# 1                    0.863030  0.585570                       0.412030
# 2                    0.858131  0.620071                       0.367007
# 3                    0.927000  0.660000                       0.357000
# 4                    1.052000  0.572000                       0.343000
# ..                        ...       ...                            ...
# 777                  0.713000  0.489000                       0.016000
# 778                  0.909000  0.495000                       0.154000
# 779                  1.042000  0.417000                       0.162000
# 780                  0.838000  0.345000                       0.034000
# 781                  0.428000  0.382000                       0.167000
#
#      Generosity  Dystopia Residual  Avg Happiness Rank
# 0      0.296780           2.517380                 3.6
# 1      0.280830           2.694630                 3.6
# 2      0.290549           2.276716                 3.6
# 3      0.256000           2.276716                 3.6
# 4      0.263000           2.276716                 3.6
# ..          ...                ...                 ...
# 777    0.185000           0.554633                15.4
# 778    0.179000           0.554633                24.4
# 779    0.191000           0.554633                24.4
# 780    0.185000           0.554633                16.8
# 781    0.269000           0.554633                24.0
#
# [782 rows x 13 columns]

# %%
data = dict(type = 'choropleth', 
           locations = wh['Country'],
           locationmode = 'country names',
           z = wh['Happiness Score'], 
           text = wh['Country'],
           colorbar = {'title':'Happiness'})
layout = dict(title = 'Happiness Index', 
             geo = dict(showframe = False, 
                       projection = {'type': 'Mercator'}))
# choromap3 = go.Figure(data = [data], layout=layout)
iplot(choromap3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8edddac236bd> in <module>
#       9                        projection = {'type': 'Mercator'}))
#      10 # choromap3 = go.Figure(data = [data], layout=layout)
# ---> 11 iplot(choromap3)
#
# NameError: name 'iplot' is not defined

# %%
# data_country_rank_all_years.groupby(['Country'])

# %%
# groupby_country_df = data_country_rank_all_years.groupby(['Country'])

# %%
# groupby_country_df

# %%
# print(groupby_country_df)

# %%
# groupby_country_df.mean()
