# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np

# %%
#import Cleaned Data
clean_data = pd.read_csv('Resources/clean_data/data_country_rankings_all_years.csv')

# %%
clean_data.sort_values("Economy (GDP per Capita)", ascending=False)
# Out:
#     Year               Country                       Region  Happiness Rank  \
# 98  2018  United Arab Emirates                          NaN              20
# 82  2017            Luxembourg                          NaN              18
# 81  2016            Luxembourg               Western Europe              20
# 97  2017  United Arab Emirates                          NaN              21
# 17  2017                Norway                          NaN               1
# ..   ...                   ...                          ...             ...
# 58  2018            Costa Rica                          NaN              13
# 79  2019                Brazil                          NaN              32
# 78  2018                Brazil                          NaN              28
# 75  2015                Brazil  Latin America and Caribbean              16
# 55  2015            Costa Rica  Latin America and Caribbean              12
#
# ...

# %%
cleaned_region = clean_data.ffill(axis = 0)
cleaned_region
# Out:
#     Year               Country                           Region  \
# 0   2015           Switzerland                   Western Europe
# 1   2016           Switzerland                   Western Europe
# 2   2017           Switzerland                   Western Europe
# 3   2018           Switzerland                   Western Europe
# 4   2019           Switzerland                   Western Europe
# ..   ...                   ...                              ...
# 95  2015  United Arab Emirates  Middle East and Northern Africa
# 96  2016  United Arab Emirates  Middle East and Northern Africa
# 97  2017  United Arab Emirates  Middle East and Northern Africa
# 98  2018  United Arab Emirates  Middle East and Northern Africa
# 99  2019  United Arab Emirates  Middle East and Northern Africa
#
#     Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                1            7.587                  1.396510  1.349510
# ...

# %%
grouped_country_df = cleaned_region.groupby(['Country'])

print(grouped_country_df)
sum_hapiness = grouped_country_df["Happiness Score"].mean()
sum_hapiness
# Out:
# ...
# Country
# Australia               7.2762
# Austria                 7.1420
# Belgium                 6.9214
# Brazil                  6.6578
# Canada                  7.3506
# Costa Rica              7.1262
# Denmark                 7.5460
# Finland                 7.5378
# Iceland                 7.5110
# Ireland                 6.9644
# Israel                  7.1422
# Luxembourg              6.9360
# Mexico                  6.7252
# Netherlands             7.4046
# New Zealand             7.3130
# Norway                  7.5410
# Sweden                  7.3192
# Switzerland             7.5114
# United Arab Emirates    6.7442
# United States           6.9988
# Name: Happiness Score, dtype: float64

# %%
sum_hapiness.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
GDP = grouped_country_df["Economy (GDP per Capita)"].mean()
GDP.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
by_country = grouped_country_df['Economy (GDP per Capita)'].sum()
by_country
# Out:
# Country
# Australia               6.974425
# Austria                 6.991707
# Belgium                 6.876991
# Brazil                  5.166133
# Canada                  6.940644
# Costa Rica              5.178276
# Denmark                 6.983643
# Finland                 6.784802
# Iceland                 6.932613
# Ireland                 7.302077
# Israel                  6.518612
# Luxembourg              8.188374
# Mexico                  5.396804
# Netherlands             7.055065
# New Zealand             6.587546
# Norway                  7.596903
# Sweden                  7.019907
# Switzerland             7.360820
# United Arab Emirates    8.226133
# United States           7.279729
# Name: Economy (GDP per Capita), dtype: float64

# %%
by_country/5
# Out:
# Country
# Australia               1.394885
# Austria                 1.398341
# Belgium                 1.375398
# Brazil                  1.033227
# Canada                  1.388129
# Costa Rica              1.035655
# Denmark                 1.396729
# Finland                 1.356960
# Iceland                 1.386523
# Ireland                 1.460415
# Israel                  1.303722
# Luxembourg              1.637675
# Mexico                  1.079361
# Netherlands             1.411013
# New Zealand             1.317509
# Norway                  1.519381
# Sweden                  1.403981
# Switzerland             1.472164
# United Arab Emirates    1.645227
# United States           1.455946
# Name: Economy (GDP per Capita), dtype: float64

# %%
plt.bar(cleaned_region["Happiness Score"], 'Country', color='r', alpha = 0.5, align="center")
# Out:
# <BarContainer object of 100 artists>
