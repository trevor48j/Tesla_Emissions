# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np

# %%
data_country_rank_all_years = pd.read_csv('./Resources/clean_data/data_country_rankings_all_years.csv')

# %%
data_country_rank_all_years
# Out:
#     Year               Country                           Region  \
# 0   2015           Switzerland                   Western Europe
# 1   2016           Switzerland                   Western Europe
# 2   2017           Switzerland                              NaN
# 3   2018           Switzerland                              NaN
# 4   2019           Switzerland                              NaN
# ..   ...                   ...                              ...
# 95  2015  United Arab Emirates  Middle East and Northern Africa
# 96  2016  United Arab Emirates  Middle East and Northern Africa
# 97  2017  United Arab Emirates                              NaN
# 98  2018  United Arab Emirates                              NaN
# 99  2019  United Arab Emirates                              NaN
#
#     Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 0                1            7.587                  1.396510  1.349510
# ...

# %%
data_country_rank_all_years.groupby(['Country'])

# %%
groupby_country_df = data_country_rank_all_years.groupby(['Country'])

# %%
groupby_country_df

# %%
print(groupby_country_df)

# %%
groupby_country_df.mean()
# Out:
#                         Year  Happiness Rank  Happiness Score  \
# Country
# Australia             2017.0            10.0           7.2762
# Austria               2017.0            12.0           7.1420
# Belgium               2017.0            17.6           6.9214
# Brazil                2017.0            23.0           6.6578
# Canada                2017.0             6.8           7.3506
# Costa Rica            2017.0            12.6           7.1262
# Denmark               2017.0             2.2           7.5460
# Finland               2017.0             3.6           7.5378
# Iceland               2017.0             3.2           7.5110
# Ireland               2017.0            16.4           6.9644
# Israel                2017.0            13.0           7.1422
# Luxembourg            2017.0            17.2           6.9360
# Mexico                2017.0            21.4           6.7252
# Netherlands           2017.0             6.2           7.4046
# ...

# %%
x_axis=
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-3010c8462bb4> in <module>
# ----> 1 plt.bar(x_axis="Country", y_axis="Economy GDP per Capita", height=10, color='b', aling='center')
#
# TypeError: bar() missing 1 required positional argument: 'x'

# %%
plt.bar(x_axis="Country", y_axis="Economy GDP per Capita", height=10, color='b', aling='center')
